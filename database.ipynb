# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Veri setini yükleme
data = pd.read_csv("/content/drive/MyDrive/melike Yalçın Kaplan/waves.csv")

# İlk 5 satırı görüntüle
print(data.head())
# Out:
#    SOURCE_ID  WAVE_ID  YEAR  MONTH  DAY  REGION_CODE COUNTRY STATE/PROVINCE  \
# 0          1    11014 -2000    NaN  NaN         50.0   SYRIA            NaN
# 1          3    17601 -1610    NaN  NaN         50.0   SYRIA            NaN
# 2          3        1 -1610    NaN  NaN         50.0  GREECE            NaN
# 3          9        2  -479    NaN  NaN         50.0  GREECE            NaN
# 4         10    19364  -426    6.0  NaN         50.0  GREECE            NaN
#
#                 LOCATION  LATITUDE  ...  INJURIES  INJURY_ESTIMATE  \
# 0                 UGARIT    35.583  ...       NaN              NaN
# 1                 UGARIT    35.583  ...       NaN              NaN
# 2  N. AND E. COAST CRETE    35.500  ...       NaN              NaN
# 3    POTIDAEA, MACEDONIA    40.300  ...       NaN              NaN
# 4                  TARFI       NaN  ...       NaN              NaN
#
#    FATALITIES  FATALITY_ESTIMATE DAMAGE_MILLIONS_DOLLARS  DAMAGE_ESTIMATE  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming data is loaded into a DataFrame named 'df'

# Count events per year
yearly_counts = data['YEAR'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_counts.index, y=yearly_counts)
plt.title('Number of Tsunami Events per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# Geographic distribution (assuming latitude and longitude are available)
import folium
# ... (Create a base map and add markers for each event)

# Correlation between magnitude and fatalities (if magnitude data is available)
sns.scatterplot(x='magnitude', y='FATALITIES', data=data)
plt.title('Correlation between Magnitude and Fatalities')
plt.xlabel('Magnitude')
plt.ylabel('Fatalities')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b33d3f1a2ab4> in <cell line: 21>()
#      19
#      20 # Correlation between magnitude and fatalities (if magnitude data is available)
# ---> 21 sns.scatterplot(x='magnitude', y='FATALITIES', data=data)
#      22 plt.title('Correlation between Magnitude and Fatalities')
#      23 plt.xlabel('Magnitude')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# ...
